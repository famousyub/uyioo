# %%
import pandas as pd

df = pd.read_csv(r'filmdata.csv')
#print(df)



Dup_Rows = df[df.duplicated()]

print("\n\nDuplicate Rows : \n {}".format(Dup_Rows))
df.head()

df.info()
df["Review"]
# Out:
# Duplicate Rows :
#  Empty DataFrame
# Columns: [Review_Date, Author, Rating, Review_Title, Review, Review_Url]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5438 entries, 0 to 5437
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Review_Date   5438 non-null   object
#  1   Author        5438 non-null   object
#  2   Rating        5314 non-null   float64
#  3   Review_Title  5438 non-null   object
#  4   Review        5436 non-null   object
#  5   Review_Url    5438 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 255.0+ KB
# 0       A lot has been said and written about Interste...
# 1       Interstellar is a movie like no other. Unlike ...
# 2       A science-fiction masterpiece. Nolan executes ...
# 3       I think just about everything has been said ab...
# 4       Amongst the best movies of all time. The story...
#                               ...
# ...

# %%
from textblob import TextBlob


for   text  in   df["Review"] : 
    blob = TextBlob(text)
    print(blob.sentiment.polarity)
    #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
# Out:
# 0.18214285714285716
# 0.32083333333333336
# 0.525
# 0.1545454545454545
# 0.36
# 0.0
# 0.22527056277056276
# -0.09999999999999999
# 0.19427083333333334
# 0.30925925925925923
# 0.0
# 0.1955463728191001
# -0.05681818181818182
# 0.05833333333333334
# 0.23092775041050906
# 0.0
# 0.4916666666666667
# 0.1619047619047619
# 0.4757142857142857
# 0.6833333333333335
# 0.15370879120879116
# 0.16897546897546897
# 0.3648148148148148
# 0.13636363636363635
# 0.16005291005291006
# 0.37916666666666665
# 0.1691904761904762
# 0.0
# 0.11477272727272729
# -0.0875
# 0.24318181818181817
# 0.1693181818181818
# 0.005952380952380952
# 0.21457215007215003
# 0.0
# 0.07857142857142856
# 0.13957274609448522
# 0.028042328042328042
# -0.06771284271284271
# 0.04583333333333334
# 0.6
# 0.1423136645962733
# 0.31313492063492065
# 0.495
# 0.26785714285714285
# 0.34518678160919536
# 0.07500000000000001
# 0.625
# 0.25833333333333336
# 0.5
# -0.0625
# 0.003703703703703709
# 0.0
# -0.075
# 0.2616071428571429
# ...
